# %% [markdown]
# # BRSM Assignment 2
#
# ## Regression Analysis

# %%
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# importing the dataset
housing_data = pd.read_csv('housing.csv')
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# replacing the non-numeric values with numeric values

housing_data['ocean_proximity'] = housing_data['ocean_proximity'].replace(['NEAR BAY', 'NEAR OCEAN', 'INLAND', '<1H OCEAN', 'ISLAND'], [0, 1, 2, 3, 4])
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0         8.3252            452600.0                0
# 1      2401.0      1138.0         8.3014            358500.0                0
# 2       496.0       177.0         7.2574            352100.0                0
# 3       558.0       219.0         5.6431            341300.0                0
# 4       565.0       259.0         3.8462            342200.0                0

# %%
housing_data.corr().style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_ac396_row0_col0, #T_ac396_row1_col1, #T_ac396_row2_col2, #T_ac396_row3_col3, #T_ac396_row4_col4, #T_ac396_row5_col5, #T_ac396_row6_col6, #T_ac396_row7_col7, #T_ac396_row8_col8, #T_ac396_row9_col9 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ac396_row0_col1, #T_ac396_row1_col0, #T_ac396_row1_col8, #T_ac396_row1_col9, #T_ac396_row2_col3, #T_ac396_row2_col4, #T_ac396_row2_col5, #T_ac396_row2_col6, #T_ac396_row2_col7, #T_ac396_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_ac396_row0_col2 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_ac396_row0_col3, #T_ac396_row4_col9 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_ac396_row0_col4, #T_ac396_row3_col9 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_ac396_row0_col5 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_ac396_row0_col6, #T_ac396_row1_col2, #T_ac396_row9_col1, #T_ac396_row9_col3 {
# ...

# %%
# Do linear regression on dataset

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X = housing_data.iloc[:, :-2].values
y = housing_data.iloc[:, -2].values

# replace nan values with 0 in X and y
X = np.nan_to_num(X)
y = np.nan_to_num(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(np.unique(X_train))
# Out:
# [ -124.35  -124.3   -124.27 ... 32054.   32627.   35682.  ]

# %%
# Training the Simple Linear Regression model on the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [210261.29309685 281627.97807923 191472.00005979 ...  81330.74448352
#  280475.90886555 207147.98900476]

# %%
# calculate VIF for each feature

from statsmodels.stats.outliers_influence import variance_inflation_factor
